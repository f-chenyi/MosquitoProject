# %%
using Pkg
Pkg.activate("../")
# Out:
#   Activating new project at `/Volumes/Chenyi/MIT/mosquito_inference/MosquitoProject`

# %%
Pkg.add("CSV")
# Out:
#    Resolving package versions...
#    Installed SentinelArrays ─ v1.4.8
#    Installed InlineStrings ── v1.4.3
#    Installed Tables ───────── v1.12.0
#    Installed FilePathsBase ── v0.9.24
#    Installed CSV ──────────── v0.10.15
#     Updating `/Volumes/Chenyi/MIT/mosquito_inference/MosquitoProject/Project.toml`
#   [336ed68f] + CSV v0.10.15
#     Updating `/Volumes/Chenyi/MIT/mosquito_inference/MosquitoProject/Manifest.toml`
#   [336ed68f] + CSV v0.10.15
#   [944b1d66] + CodecZlib v0.7.8
#   [34da2185] + Compat v4.16.0
#   [9a962f9c] + DataAPI v1.16.0
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [48062228] + FilePathsBase v0.9.24
#   [842dd82b] + InlineStrings v1.4.3
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [bac558e1] + OrderedCollections v1.8.0
#   [69de0a69] + Parsers v2.8.3
#   [2dfb63ee] + PooledArrays v1.4.3
# ⌅ [aea7be01] + PrecompileTools v1.2.1
#   [21216c6a] + Preferences v1.4.3
#   [91c51154] + SentinelArrays v1.4.8
#   [3783bdb8] + TableTraits v1.0.1
# ...

# %%
Pkg.add("DelimitedFiles")
# Out:
#    Resolving package versions...
#     Updating `/Volumes/Chenyi/MIT/mosquito_inference/MosquitoProject/Project.toml`
#   [8bb1440f] + DelimitedFiles v1.9.1
#     Updating `/Volumes/Chenyi/MIT/mosquito_inference/MosquitoProject/Manifest.toml`
#   [8bb1440f] + DelimitedFiles v1.9.1

# %%
Pkg.add("Dates")
# Out:
#    Resolving package versions...
#     Updating `/Volumes/Chenyi/MIT/mosquito_inference/MosquitoProject/Project.toml`
#   [ade2ca70] + Dates
#   No Changes to `/Volumes/Chenyi/MIT/mosquito_inference/MosquitoProject/Manifest.toml`

# %%
Pkg.add("DataFrames")
# Out:
#    Resolving package versions...
#    Installed InvertedIndices ─ v1.3.1
#    Installed PrettyTables ──── v2.3.2
#    Installed DataFrames ────── v1.7.0
#     Updating `/Volumes/Chenyi/MIT/mosquito_inference/MosquitoProject/Project.toml`
#   [a93c6f00] + DataFrames v1.7.0
#     Updating `/Volumes/Chenyi/MIT/mosquito_inference/MosquitoProject/Manifest.toml`
#   [a8cc5b0e] + Crayons v4.1.1
#   [a93c6f00] + DataFrames v1.7.0
#   [864edb3b] + DataStructures v0.18.22
#   [41ab1584] + InvertedIndices v1.3.1
#   [b964fa9f] + LaTeXStrings v1.4.0
#   [e1d29d7a] + Missings v1.2.0
# ⌅ [08abe8d2] + PrettyTables v2.3.2
#   [189a3867] + Reexport v1.2.2
#   [a2af1166] + SortingAlgorithms v1.2.1
# ⌅ [892a3eda] + StringManipulation v0.3.4
#   [0dad84c5] + ArgTools v1.1.1
#   [56f22d72] + Artifacts
#   [2a0f44e3] + Base64
#   [f43a241f] + Downloads v1.6.0
#   [7b1f6079] + FileWatching
#   [b77e0a4c] + InteractiveUtils
#   [b27032c2] + LibCURL v0.6.3
#   [76f85450] + LibGit2
# ...

# %%
Pkg.add("LinearAlgebra")
# Out:
#    Resolving package versions...
#     Updating `/Volumes/Chenyi/MIT/mosquito_inference/MosquitoProject/Project.toml`
#   [37e2e46d] + LinearAlgebra
#   No Changes to `/Volumes/Chenyi/MIT/mosquito_inference/MosquitoProject/Manifest.toml`

# %%
Pkg.add("Interpolations")
# Out:
#    Resolving package versions...
#    Installed OffsetArrays ───── v1.17.0
#    Installed StaticArraysCore ─ v1.4.3
#    Installed Adapt ──────────── v4.3.0
#    Installed ChainRulesCore ─── v1.25.1
#    Installed StaticArrays ───── v1.9.13
#     Updating `/Volumes/Chenyi/MIT/mosquito_inference/MosquitoProject/Project.toml`
#   [a98d9a8b] + Interpolations v0.15.1
#     Updating `/Volumes/Chenyi/MIT/mosquito_inference/MosquitoProject/Manifest.toml`
#   [79e6a3ab] + Adapt v4.3.0
#   [13072b0f] + AxisAlgorithms v1.1.0
#   [d360d2e6] + ChainRulesCore v1.25.1
#   [a98d9a8b] + Interpolations v0.15.1
#   [6fe1bfb0] + OffsetArrays v1.17.0
#   [c84ed2f1] + Ratios v0.4.5
#   [ae029012] + Requires v1.3.1
#   [90137ffa] + StaticArrays v1.9.13
#   [1e83bf80] + StaticArraysCore v1.4.3
#   [efce3f68] + WoodburyMatrices v1.0.0
#   [8ba89e20] + Distributed
#   [1a1011a3] + SharedArrays
# Precompiling project...
#   ✓ OffsetArrays
#   ✓ Adapt
#   ✓ StaticArraysCore
#   ✓ ChainRulesCore
# ...

# %%
Pkg.add("JLD")
# Out:
#    Resolving package versions...
#    Installed MPICH_jll ───────── v4.3.0+1
#    Installed MicrosoftMPI_jll ── v10.1.4+3
#    Installed OpenMPI_jll ─────── v5.0.7+2
#    Installed H5Zblosc ────────── v0.1.2
#    Installed Hwloc_jll ───────── v2.12.0+0
#    Installed MPIPreferences ──── v0.1.11
#    Installed FileIO ──────────── v1.17.0
#    Installed libaec_jll ──────── v1.1.3+0
#    Installed JLD ─────────────── v0.13.5
#    Installed Blosc_jll ───────── v1.21.7+0
#    Installed MPItrampoline_jll ─ v5.5.3+0
#    Installed Lz4_jll ─────────── v1.10.1+0
#    Installed HDF5_jll ────────── v1.14.6+0
#    Installed HDF5 ────────────── v0.17.2
#     Updating `/Volumes/Chenyi/MIT/mosquito_inference/MosquitoProject/Project.toml`
#   [4138dd39] + JLD v0.13.5
#     Updating `/Volumes/Chenyi/MIT/mosquito_inference/MosquitoProject/Manifest.toml`
#   [a74b3585] + Blosc v0.7.3
#   [5789e2e9] + FileIO v1.17.0
#   [c8ec2601] + H5Zblosc v0.1.2
#   [f67ccb44] + HDF5 v0.17.2
# ...

# %%
Pkg.add("MAT")
# Out:
#    Resolving package versions...
#    Installed BufferedStreams ─ v1.2.2
#    Installed MAT ───────────── v0.10.7
#     Updating `/Volumes/Chenyi/MIT/mosquito_inference/MosquitoProject/Project.toml`
#   [23992714] + MAT v0.10.7
#     Updating `/Volumes/Chenyi/MIT/mosquito_inference/MosquitoProject/Manifest.toml`
#   [e1450e63] + BufferedStreams v1.2.2
#   [23992714] + MAT v0.10.7
# Precompiling project...
#   ✓ BufferedStreams
#   ✓ MAT
#   2 dependencies successfully precompiled in 3 seconds. 73 already precompiled.

# %%
Pkg.add("Statistics")
# Out:
#    Resolving package versions...
#     Updating `/Volumes/Chenyi/MIT/mosquito_inference/MosquitoProject/Project.toml`
#   [10745b16] + Statistics v1.9.0
#   No Changes to `/Volumes/Chenyi/MIT/mosquito_inference/MosquitoProject/Manifest.toml`

# %%
Pkg.add("DifferentialEquations")
# Out:
#    Resolving package versions...
#    Installed Polyester ──────────────────────── v0.7.16
#    Installed EnumX ──────────────────────────── v1.0.5
#    Installed HypergeometricFunctions ────────── v0.3.28
#    Installed PDMats ─────────────────────────── v0.11.31
#    Installed RecursiveArrayTools ────────────── v3.3.3
#    Installed StatsFuns ──────────────────────── v1.4.0
#    Installed DifferentialEquations ──────────── v7.13.0
#    Installed NonlinearSolve ─────────────────── v3.4.0
#    Installed IntelOpenMP_jll ────────────────── v2025.0.4+0
#    Installed RandomNumbers ──────────────────── v1.6.0
#    Installed CEnum ──────────────────────────── v0.5.0
#    Installed MaybeInplace ───────────────────── v0.1.4
#    Installed TriangularSolve ────────────────── v0.1.20
#    Installed Static ─────────────────────────── v0.8.9
#    Installed Distances ──────────────────────── v0.10.12
#    Installed Tricks ─────────────────────────── v0.1.10
# ...

# %%
Pkg.add("StatsBase")
# Out:
#    Resolving package versions...
#     Updating `/Volumes/Chenyi/MIT/mosquito_inference/MosquitoProject/Project.toml`
# ⌅ [2913bbd2] + StatsBase v0.34.4
#   No Changes to `/Volumes/Chenyi/MIT/mosquito_inference/MosquitoProject/Manifest.toml`

# %%
Pkg.add("Plots")
# Out:
#    Resolving package versions...
#     Updating `/Volumes/Chenyi/MIT/mosquito_inference/MosquitoProject/Project.toml`
#   [91a5bcdd] + Plots v1.40.13
#     Updating `/Volumes/Chenyi/MIT/mosquito_inference/MosquitoProject/Manifest.toml`
#   [d1d4a3ce] + BitFlags v0.1.9
#   [35d6a980] + ColorSchemes v3.29.0
#   [3da002f7] + ColorTypes v0.12.1
#   [c3611d14] + ColorVectorSpace v0.11.0
#   [5ae59095] + Colors v0.13.0
#   [f0e56b4a] + ConcurrentUtilities v2.5.0
#   [d38c429a] + Contour v0.6.3
#   [460bff9d] + ExceptionUnwrapping v0.1.11
#   [c87230d0] + FFMPEG v0.4.2
#   [53c48c17] + FixedPointNumbers v0.8.5
#   [1fa38f19] + Format v1.3.7
#   [28b8d3ca] + GR v0.73.14
#   [42e2da0e] + Grisu v1.0.2
#   [cd3eb016] + HTTP v1.10.16
#   [1019f520] + JLFzf v0.1.11
#   [682c06a0] + JSON v0.21.4
#   [23fbe1c1] + Latexify v0.16.7
#   [e6f89c97] + LoggingExtras v1.1.0
#   [739be429] + MbedTLS v1.1.9
#   [442fdcdd] + Measures v0.3.2
#   [4d8831e6] + OpenSSL v1.4.3
#   [ccf2f8ad] + PlotThemes v3.3.0
# ...
